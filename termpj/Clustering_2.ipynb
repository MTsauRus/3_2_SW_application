# %%
import pandas as pd

# %%
df1 = pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\UseThisData.xlsx')
df1.head()

# %%
df1.head();

# %%
df1.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
import seaborn as sns
df1['cap-shape'].value_counts()
# Out:
# x    26934
# f    13404
# s     7164
# b     5694
# o     3460
# p     2598
# c     1815
# Name: cap-shape, dtype: int64

# %%
sns.countplot(data=df1, x='cap-color', hue='class')
# Out:
# <AxesSubplot:xlabel='cap-color', ylabel='count'>

# %%
df1.groupby(["cap-shape", "class"]).size()
# Out:
# cap-shape  class
# b          e         1258
#            p         4436
# c          e          774
#            p         1041
# f          e         6502
#            p         6902
# o          e          825
#            p         2635
# p          e         1567
#            p         1031
# s          e         3295
#            p         3869
# x          e        12960
#            p        13974
# dtype: int64

# %%
df1.groupby(["cap-shape", "class"]).size().reset_index(name="Time")
# Out:
#    cap-shape class   Time
# 0          b     e   1258
# 1          b     p   4436
# 2          c     e    774
# 3          c     p   1041
# 4          f     e   6502
# 5          f     p   6902
# 6          o     e    825
# 7          o     p   2635
# 8          p     e   1567
# 9          p     p   1031
# 10         s     e   3295
# 11         s     p   3869
# 12         x     e  12960
# 13         x     p  13974

# %% [markdown]
# - 위의 방법으로 세 개의 컬럼을 동일하게 적용
# - ex) subdf1 = 위의 식
# subdf3까지 만든 후 엑셀파일로 내보낸 다음 손으로 비율을 구해보자.

# %%
cap_color1 = df1.groupby(["cap-color", "class"]).size().reset_index(name="Time")

# %%
cap_color1.head()
# Out:
#   cap-color class  Time
# 0         b     e   974
# 1         b     p   256
# 2         e     e   880
# 3         e     p  3155
# 4         g     e  2297

# %%
gill_color1=df1.groupby(["gill-color", "class"]).size().reset_index(name="Time")

# %%
stem_color1=df1.groupby(["stem-color", "class"]).size().reset_index(name="Time")

# %%
veil_color1=df1.groupby(["veil-color", "class"]).size().reset_index(name="Time")

# %%
gill_color1.head()
# Out:
#   gill-color class  Time
# 0          b     e   710
# 1          b     p   244
# 2          e     e   279
# 3          e     p   787
# 4          f     e  1412

# %%
stem_color1.head()
# Out:
#   stem-color class  Time
# 0          b     e   173
# 1          e     e   538
# 2          e     p  1512
# 3          f     p  1059
# 4          g     e  1594

# %%
stem_color1
# Out:
#    stem-color class   Time
# 0           b     e    173
# 1           e     e    538
# 2           e     p   1512
# 3           f     p   1059
# 4           g     e   1594
# 5           g     p   1032
# 6           k     e    189
# 7           k     p    648
# 8           l     e    105
# 9           l     p    121
# 10          n     e   7308
# 11          n     p  10755
# 12          o     e    858
# 13          o     p   1329
# 14          p     e    132
# 15          p     p    893
# 16          r     e    114
# 17          r     p    428
# 18          u     e    533
# 19          u     p    957
# 20          w     e  13143
# 21          w     p   9783
# 22          y     e   2494
# 23          y     p   5371

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# Todo: cap_color1,gill_color1,stem_color1, veil_color1

# %%
cap_color1.to_excel('capColor.xlsx')

# %%
gill_color1.to_excel('gillColor.xlsx')
stem_color1.to_excel('stemColor.xlsx')
veil_color1.to_excel('veilColor.xlsx')

# %%
df1 = pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\UseThisRatio.xlsx')
df1.head();

# %%
df1.head()
# Out:
#    Unnamed: 0 cap-color  E_RATIO1 gill-color  E_RATIO2 stem-color  E_RATIO3  \
# 0           0         b  0.791870          b  0.744235          b  1.000000
# 1           1         e  0.218092          e  0.261726          e  0.262439
# 2           2         f       NaN          f  0.400000          f  0.000000
# 3           3         g  0.519683          g  0.528169          g  0.607007
# 4           4         k  0.391712          k  0.390737          k  0.225806
#
#   veil-color  E_RATIO4
# 0        NaN       NaN
# 1          e       0.0
# 2        NaN       NaN
# 3        NaN       NaN
# 4          k       0.0

# %%
df1 = pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\UseThisData.xlsx')
df1.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  Unnamed: 104  \
# 0               e          NaN          w        16.95  ...           NaN
# 1               e          NaN          w        17.99  ...           NaN
# 2               e          NaN          w        17.80  ...           NaN
# 3               e          NaN          w        15.77  ...           NaN
# 4               e          NaN          w        16.53  ...           NaN
#
#   Unnamed: 105 Unnamed: 106 Unnamed: 107 Unnamed: 108 Unnamed: 109  \
# ...

# %%
df1 = pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\UseThisData.xlsx')
df1.head()
# df1 is total data
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
df2 = pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\UseThisRatio.xlsx')
df2.head()
# df2 is ratio of color data
# Out:
#   cap-color  E_RATIO1 gill-color  E_RATIO2 stem-color  E_RATIO3 veil-color  \
# 0         b  0.791870          b  0.744235          b  1.000000        NaN
# 1         e  0.218092          e  0.261726          e  0.262439          e
# 2         f       NaN          f  0.400000          f  0.000000        NaN
# 3         g  0.519683          g  0.528169          g  0.607007        NaN
# 4         k  0.391712          k  0.390737          k  0.225806          k
#
#    E_RATIO4
# 0       NaN
# 1       0.0
# 2       NaN
# 3       NaN
# 4       0.0

# %%
df2
# Out:
#    cap-color  E_RATIO1 gill-color  E_RATIO2 stem-color  E_RATIO3 veil-color  \
# 0          b  0.791870          b  0.744235          b  1.000000        NaN
# 1          e  0.218092          e  0.261726          e  0.262439          e
# 2          f       NaN          f  0.400000          f  0.000000        NaN
# 3          g  0.519683          g  0.528169          g  0.607007        NaN
# 4          k  0.391712          k  0.390737          k  0.225806          k
# 5          l  0.545894          l       NaN          l  0.464602        NaN
# 6          n  0.512305          n  0.309279          n  0.404584          n
# 7          o  0.292943          o  0.420419          o  0.392318        NaN
# 8          p  0.263652          p  0.412001          p  0.128780        NaN
# 9          r  0.111111          r  0.379557          r  0.210332        NaN
# 10         u  0.357519          u  0.428152          u  0.357718          u
# ...

# %%
df2.to_excel('color_edible_ratio.xlsx')

# %%
df3=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\ColorIndexRatio_FINAL.xlsx')

# %%
df3
# Out:
#    COLOR  cap_edibleRatio  gill_edibleRatio  stem_edibleRatio  \
# 0      b         0.791870          0.744235          1.000000
# 1      e         0.218092          0.261726          0.262439
# 2      f              NaN          0.400000          0.000000
# 3      g         0.519683          0.528169          0.607007
# 4      k         0.391712          0.390737          0.225806
# 5      l         0.545894               NaN          0.464602
# 6      n         0.512305          0.309279          0.404584
# 7      o         0.292943          0.420419          0.392318
# 8      p         0.263652          0.412001          0.128780
# 9      r         0.111111          0.379557          0.210332
# 10     u         0.357519          0.428152          0.357718
# 11     w         0.489173          0.545705          0.573279
# 12     y         0.420344          0.411691          0.317101
#
#     veil_edibleRatio
# 0                NaN
# 1           0.000000
# 2                NaN
# ...

# %%
import pandas as pd
df3=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\ColorIndexRatio_FINAL.xlsx')
df3
# Out:
#    COLOR  cap_edibleRatio  gill_edibleRatio  stem_edibleRatio  \
# 0      b         0.791870          0.744235          1.000000
# 1      e         0.218092          0.261726          0.262439
# 2      f              NaN          0.400000          0.000000
# 3      g         0.519683          0.528169          0.607007
# 4      k         0.391712          0.390737          0.225806
# 5      l         0.545894               NaN          0.464602
# 6      n         0.512305          0.309279          0.404584
# 7      o         0.292943          0.420419          0.392318
# 8      p         0.263652          0.412001          0.128780
# 9      r         0.111111          0.379557          0.210332
# 10     u         0.357519          0.428152          0.357718
# 11     w         0.489173          0.545705          0.573279
# 12     y         0.420344          0.411691          0.317101
#
#     veil_edibleRatio
# 0                NaN
# 1           0.000000
# 2                NaN
# ...

# %%
df3.set_index('COLOR')
# Out:
#        cap_edibleRatio  gill_edibleRatio  stem_edibleRatio  veil_edibleRatio
# COLOR
# b             0.791870          0.744235          1.000000               NaN
# e             0.218092          0.261726          0.262439          0.000000
# f                  NaN          0.400000          0.000000               NaN
# g             0.519683          0.528169          0.607007               NaN
# k             0.391712          0.390737          0.225806          0.000000
# l             0.545894               NaN          0.464602               NaN
# n             0.512305          0.309279          0.404584          0.000000
# o             0.292943          0.420419          0.392318               NaN
# p             0.263652          0.412001          0.128780               NaN
# r             0.111111          0.379557          0.210332               NaN
# u             0.357519          0.428152          0.357718          0.000000
# ...

# %%
import pandas as pd
df3=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\ColorIndexRatio_FINAL.xlsx')
df3
# Out:
#    COLOR  cap_edibleRatio  gill_edibleRatio  stem_edibleRatio  \
# 0      b         0.791870          0.744235          1.000000
# 1      e         0.218092          0.261726          0.262439
# 2      f              NaN          0.400000          0.000000
# 3      g         0.519683          0.528169          0.607007
# 4      k         0.391712          0.390737          0.225806
# 5      l         0.545894               NaN          0.464602
# 6      n         0.512305          0.309279          0.404584
# 7      o         0.292943          0.420419          0.392318
# 8      p         0.263652          0.412001          0.128780
# 9      r         0.111111          0.379557          0.210332
# 10     u         0.357519          0.428152          0.357718
# 11     w         0.489173          0.545705          0.573279
# 12     y         0.420344          0.411691          0.317101
#
#     veil_edibleRatio
# 0                NaN
# 1           0.000000
# 2                NaN
# ...

# %%
df3.set_index('COLOR')
# Out:
#        cap_edibleRatio  gill_edibleRatio  stem_edibleRatio  veil_edibleRatio
# COLOR
# b             0.791870          0.744235          1.000000               NaN
# e             0.218092          0.261726          0.262439          0.000000
# f                  NaN          0.400000          0.000000               NaN
# g             0.519683          0.528169          0.607007               NaN
# k             0.391712          0.390737          0.225806          0.000000
# l             0.545894               NaN          0.464602               NaN
# n             0.512305          0.309279          0.404584          0.000000
# o             0.292943          0.420419          0.392318               NaN
# p             0.263652          0.412001          0.128780               NaN
# r             0.111111          0.379557          0.210332               NaN
# u             0.357519          0.428152          0.357718          0.000000
# ...

# %%
cap_ratio = df3.groupby('cap_edibleRatio')

# %%
cap_ratio

# %%
cap_ratio = df3['cap_edibleRatio']

# %%
cap_ratio
# Out:
# 0     0.791870
# 1     0.218092
# 2          NaN
# 3     0.519683
# 4     0.391712
# 5     0.545894
# 6     0.512305
# 7     0.292943
# 8     0.263652
# 9     0.111111
# 10    0.357519
# 11    0.489173
# 12    0.420344
# Name: cap_edibleRatio, dtype: float64

# %%
gill_ratio=df3['gill_edibleRatio']

# %%
stem_ratio=df3['stem_edibleRatio']

# %%
capXgill=cap_ratio.mul(gill_ratio)

# %%
capXgill
# Out:
# 0     0.589337
# 1     0.057080
# 2          NaN
# 3     0.274481
# 4     0.153056
# 5          NaN
# 6     0.158445
# 7     0.123159
# 8     0.108625
# 9     0.042173
# 10    0.153073
# 11    0.266944
# 12    0.173052
# dtype: float64

# %%
gill_ratio_T=gill_ratio.transpose()

# %%
gill_ratio_T
# Out:
# 0     0.744235
# 1     0.261726
# 2     0.400000
# 3     0.528169
# 4     0.390737
# 5          NaN
# 6     0.309279
# 7     0.420419
# 8     0.412001
# 9     0.379557
# 10    0.428152
# 11    0.545705
# 12    0.411691
# Name: gill_edibleRatio, dtype: float64

# %%
gill_ratio
# Out:
# 0     0.744235
# 1     0.261726
# 2     0.400000
# 3     0.528169
# 4     0.390737
# 5          NaN
# 6     0.309279
# 7     0.420419
# 8     0.412001
# 9     0.379557
# 10    0.428152
# 11    0.545705
# 12    0.411691
# Name: gill_edibleRatio, dtype: float64

# %%
df3
# Out:
#        cap_edibleRatio  gill_edibleRatio  stem_edibleRatio  veil_edibleRatio
# COLOR
# b             0.791870          0.744235          1.000000               NaN
# e             0.218092          0.261726          0.262439          0.000000
# f                  NaN          0.400000          0.000000               NaN
# g             0.519683          0.528169          0.607007               NaN
# k             0.391712          0.390737          0.225806          0.000000
# l             0.545894               NaN          0.464602               NaN
# n             0.512305          0.309279          0.404584          0.000000
# o             0.292943          0.420419          0.392318               NaN
# p             0.263652          0.412001          0.128780               NaN
# r             0.111111          0.379557          0.210332               NaN
# u             0.357519          0.428152          0.357718          0.000000
# ...

# %%
df3_T=df3.transpose()
df3_T
# Out:
# COLOR                    b         e    f         g         k         l  \
# cap_edibleRatio   0.791870  0.218092  NaN  0.519683  0.391712  0.545894
# gill_edibleRatio  0.744235  0.261726  0.4  0.528169  0.390737       NaN
# stem_edibleRatio  1.000000  0.262439  0.0  0.607007  0.225806  0.464602
# veil_edibleRatio       NaN  0.000000  NaN       NaN  0.000000       NaN
#
# COLOR                    n         o         p         r         u         w  \
# cap_edibleRatio   0.512305  0.292943  0.263652  0.111111  0.357519  0.489173
# gill_edibleRatio  0.309279  0.420419  0.412001  0.379557  0.428152  0.545705
# stem_edibleRatio  0.404584  0.392318  0.128780  0.210332  0.357718  0.573279
# veil_edibleRatio  0.000000       NaN       NaN       NaN  0.000000  0.484107
#
# COLOR                    y
# cap_edibleRatio   0.420344
# gill_edibleRatio  0.411691
# stem_edibleRatio  0.317101
# veil_edibleRatio  1.000000

# %%
CapGill=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\CapGillColor.xlsx')

# %%
CapGill
# Out:
#     b  0.791869918699187  0.7442348008385744
# 0   e           0.218092            0.261726
# 1   f                NaN            0.400000
# 2   g           0.519683            0.528169
# 3   k           0.391712            0.390737
# 4   l           0.545894                 NaN
# 5   n           0.512305            0.309279
# 6   o           0.292943            0.420419
# 7   p           0.263652            0.412001
# 8   r           0.111111            0.379557
# 9   u           0.357519            0.428152
# 10  w           0.489173            0.545705
# 11  y           0.420344            0.411691

# %%
CapGill=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\CapGillColor.xlsx')
CapGill
# Out:
#    COLOR  cap_edibleRatio  gill_edibleRatio
# 0      b         0.791870          0.744235
# 1      e         0.218092          0.261726
# 2      f              NaN          0.400000
# 3      g         0.519683          0.528169
# 4      k         0.391712          0.390737
# 5      l         0.545894               NaN
# 6      n         0.512305          0.309279
# 7      o         0.292943          0.420419
# 8      p         0.263652          0.412001
# 9      r         0.111111          0.379557
# 10     u         0.357519          0.428152
# 11     w         0.489173          0.545705
# 12     y         0.420344          0.411691

# %%
CapGill
# Out:
#        cap_edibleRatio  gill_edibleRatio
# COLOR
# b             0.791870          0.744235
# e             0.218092          0.261726
# f                  NaN          0.400000
# g             0.519683          0.528169
# k             0.391712          0.390737
# l             0.545894               NaN
# n             0.512305          0.309279
# o             0.292943          0.420419
# p             0.263652          0.412001
# r             0.111111          0.379557
# u             0.357519          0.428152
# w             0.489173          0.545705
# y             0.420344          0.411691

# %%
CapGill_T=CapGill.T
CapGill_T
# Out:
# COLOR                    b         e    f         g         k         l  \
# cap_edibleRatio   0.791870  0.218092  NaN  0.519683  0.391712  0.545894
# gill_edibleRatio  0.744235  0.261726  0.4  0.528169  0.390737       NaN
#
# COLOR                    n         o         p         r         u         w  \
# cap_edibleRatio   0.512305  0.292943  0.263652  0.111111  0.357519  0.489173
# gill_edibleRatio  0.309279  0.420419  0.412001  0.379557  0.428152  0.545705
#
# COLOR                    y
# cap_edibleRatio   0.420344
# gill_edibleRatio  0.411691

# %%
cap=CapGill['cap_edibleRatio']
gill=CapGill['gill_edibleRatio']
cap
# Out:
# COLOR
# b    0.791870
# e    0.218092
# f         NaN
# g    0.519683
# k    0.391712
# l    0.545894
# n    0.512305
# o    0.292943
# p    0.263652
# r    0.111111
# u    0.357519
# w    0.489173
# y    0.420344
# Name: cap_edibleRatio, dtype: float64

# %%
dotTest = cap.dot(gill)
dotTest
# Out:
# nan

# %%
import itertools
L=[(x, y) for x, y in itertools.product(CapGill.columns,CapGill.columns) if x != y]

pd.concat([pd.DataFrame({''.join(i):CapGill.loc[:,i].prod(axis=1)}) for i in L],axis=1)
# Out:
#        cap_edibleRatiogill_edibleRatio  gill_edibleRatiocap_edibleRatio
# COLOR
# b                             0.589337                         0.589337
# e                             0.057080                         0.057080
# f                             0.400000                         0.400000
# g                             0.274481                         0.274481
# k                             0.153056                         0.153056
# l                             0.545894                         0.545894
# n                             0.158445                         0.158445
# o                             0.123159                         0.123159
# p                             0.108625                         0.108625
# r                             0.042173                         0.042173
# u                             0.153073                         0.153073
# w                             0.266944                         0.266944
# ...

# %%
CapGill
# Out:
#        cap_edibleRatio  gill_edibleRatio
# COLOR
# b             0.791870          0.744235
# e             0.218092          0.261726
# f                  NaN          0.400000
# g             0.519683          0.528169
# k             0.391712          0.390737
# l             0.545894               NaN
# n             0.512305          0.309279
# o             0.292943          0.420419
# p             0.263652          0.412001
# r             0.111111          0.379557
# u             0.357519          0.428152
# w             0.489173          0.545705
# y             0.420344          0.411691

# %%
CapGill.iterrows
# Out:
# <bound method DataFrame.iterrows of        cap_edibleRatio  gill_edibleRatio
# COLOR
# b             0.791870          0.744235
# e             0.218092          0.261726
# f                  NaN          0.400000
# g             0.519683          0.528169
# k             0.391712          0.390737
# l             0.545894               NaN
# n             0.512305          0.309279
# o             0.292943          0.420419
# p             0.263652          0.412001
# r             0.111111          0.379557
# u             0.357519          0.428152
# w             0.489173          0.545705
# y             0.420344          0.411691>

# %%
cap
# Out:
# COLOR
# b    0.791870
# e    0.218092
# f         NaN
# g    0.519683
# k    0.391712
# l    0.545894
# n    0.512305
# o    0.292943
# p    0.263652
# r    0.111111
# u    0.357519
# w    0.489173
# y    0.420344
# Name: cap_edibleRatio, dtype: float64

# %%
capList=list(cap)
gillList=list(gill)

# %%
capXgill=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\CapMULgill.xlsx')

# %%
capXgill
# Out:
#    Unnamed: 0         b         e         f         g         k   l         n  \
# 0           b  0.589337  0.207253  0.316748  0.418241  0.309413 NaN  0.244909
# 1           e  0.162311  0.057080  0.087237  0.115189  0.085216 NaN  0.067451
# 2           f       NaN       NaN       NaN       NaN       NaN NaN       NaN
# 3           g  0.386766  0.136015  0.207873  0.274481  0.203059 NaN  0.160727
# 4           k  0.291526  0.102521  0.156685  0.206890  0.153056 NaN  0.121149
# 5           l  0.406273  0.142875  0.218357  0.288324  0.213301 NaN  0.168834
# 6           n  0.381275  0.134084  0.204922  0.270584  0.200176 NaN  0.158445
# 7           o  0.218018  0.076671  0.117177  0.154723  0.114464 NaN  0.090601
# 8           p  0.196219  0.069005  0.105461  0.139253  0.103019 NaN  0.081542
# 9           r  0.082693  0.029081  0.044444  0.058685  0.043415 NaN  0.034364
# 10          u  0.266078  0.093572  0.143008  0.188830  0.139696 NaN  0.110573
# ...

# %%
capXgill=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\CapMULgill.xlsx')
capXgill=capXgill.set_index('COLOR')
capXgill
# Out:
#               b         e         f         g         k   l         n  \
# COLOR
# b      0.589337  0.207253  0.316748  0.418241  0.309413 NaN  0.244909
# e      0.162311  0.057080  0.087237  0.115189  0.085216 NaN  0.067451
# f           NaN       NaN       NaN       NaN       NaN NaN       NaN
# g      0.386766  0.136015  0.207873  0.274481  0.203059 NaN  0.160727
# k      0.291526  0.102521  0.156685  0.206890  0.153056 NaN  0.121149
# l      0.406273  0.142875  0.218357  0.288324  0.213301 NaN  0.168834
# n      0.381275  0.134084  0.204922  0.270584  0.200176 NaN  0.158445
# o      0.218018  0.076671  0.117177  0.154723  0.114464 NaN  0.090601
# p      0.196219  0.069005  0.105461  0.139253  0.103019 NaN  0.081542
# r      0.082693  0.029081  0.044444  0.058685  0.043415 NaN  0.034364
# u      0.266078  0.093572  0.143008  0.188830  0.139696 NaN  0.110573
# w      0.364060  0.128029  0.195669  0.258366  0.191138 NaN  0.151291
# ...

# %%
stackCG=capXgill.stack()

# %%
stackCG
# Out:
# COLOR
# b      b    0.589337
#        e    0.207253
#        f    0.316748
#        g    0.418241
#        k    0.309413
#               ...
# y      p    0.173182
#        r    0.159544
#        u    0.179971
#        w    0.229384
#        y    0.173052
# Length: 144, dtype: float64

# %%
stackCG.to_excel('CapXGill.xlsx')

# %%
CapGillStem=pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\3rd\CapXGillXStem.xlsx')
CapGillStem=CapGillStem.set_index('COLOR')

# %%
stackCGS=CapGillStem.stack()
stackCGS
# Out:
# COLOR
# b b    e    0.154665
#        g    0.357732
#        k    0.133076
#        l    0.273807
#        n    0.238436
#               ...
# y y    p    0.022286
#        r    0.036398
#        u    0.061904
#        w    0.099207
#        y    0.054875
# Length: 1584, dtype: float64

# %%
CGS_poisonous_ratio=(1-stackCGS).sort_values(ascending=False)
CGS_poisonous_ratio
# Out:
# COLOR
# l e    p    0.996255
# l n    p    0.995575
# l r    p    0.994569
# l k    p    0.994409
# l f    p    0.994276
#               ...
# b g    g    0.746125
# b w    g    0.737696
# b b    l    0.726193
#        w    0.662145
#        g    0.642268
# Length: 1584, dtype: float64

# %% [markdown]
# ### 최종
# ###### cap color, gill color, stem color 세 가지 attr에 대한 독버섯 확률
# - cap color의 각 색깔 별 식용버섯 비율 구함
# - 세 가지 attr의 식용버섯 비율을 곱함
# - 1 - (세 식용버섯 비율의 곱) = 그 attr을 가진 버섯이 독버섯일 확률. <br><br>
# 계산을 토대로, l, e, p의 속성을 가진 버섯이 가장 독버섯일 확률이 높았다.

# %%
CGS_poisonous_ratio.to_excel('CapGillStem_poisonRatio.xlsx')

# %%
print("just test")
# Out:
# just test
