# %% [markdown]
# ## DBSCAN, GOWER DISTANCE
#
# 뭘 어케 해야댐..;

# %%
print("start!")
# Out:
# start!

# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import gower
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r'C:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\MushroomDataset\4th\dataset.xlsx')
data.head(10)
# Out:
#        class  cap-diameter cap-shape   cap-color does-bruise-or-bleed  \
# 0  poisonous         15.26    convex  cap-ornage   no-bruise-or-bleed
# 1  poisonous         16.60    convex  cap-ornage   no-bruise-or-bleed
# 2  poisonous         14.07    convex  cap-ornage   no-bruise-or-bleed
# 3  poisonous         14.17      flat     cap-red   no-bruise-or-bleed
# 4  poisonous         14.64    convex  cap-ornage   no-bruise-or-bleed
# 5  poisonous         15.34    convex  cap-ornage   no-bruise-or-bleed
# 6  poisonous         14.85      flat  cap-ornage   no-bruise-or-bleed
# 7  poisonous         14.86    convex     cap-red   no-bruise-or-bleed
# 8  poisonous         12.85      flat  cap-ornage   no-bruise-or-bleed
# 9  poisonous         13.55      flat     cap-red   no-bruise-or-bleed
#
#    gill-color  stem-height  stem-width  stem-color has-ring habitat  season
# 0  gill-white        16.95       17.09  stem-white     ring   woods  winter
# ...

# %%
edibleData = data[data['class'] == 'edible']
poisonData = data[data['class'] == 'poisonous']

# %%
edibleData.drop(['class'], axis = 1, inplace = True)
poisonData.drop(['class'], axis = 1, inplace = True)
# Out:
# C:\Users\qksru\AppData\Local\Temp\ipykernel_25584\2620962772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edibleData.drop(['class'], axis = 1, inplace = True)
# C:\Users\qksru\AppData\Local\Temp\ipykernel_25584\2620962772.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poisonData.drop(['class'], axis = 1, inplace = True)

# %%
# # edibleSet[]은 먹을 수 있는 버섯 표본 중 랜덤으로 
# # 1000개를 뽑은 set의 집합. 
# edibleSet = []
# poisonSet = []
# for i in range (10):
#     _ = edibleData.sample(1000, replace = True)
#     edibleSet.append(_)
#     _ = poisonData.sample(1000, replace = True)
#     poisonSet.append(_)

littleEdibleData = edibleData.sample(5000, replace = True)
littlePoisonData = poisonData.sample(5000, replace = True)

# %%
#gowerMatList = []
# gowerEdibleMat = []
# gowerPoisonMat = []
# for i in range(9): # 랜덤 표본 10개에 대한 가워 매트릭스 계산. 
#     tmpMat = gower.gower_matrix(edibleSet[i])
#     gowerEdibleMat.append(tmpMat)
#     tmpMat = gower.gower_matrix(poisonSet[i])
#     gowerPoisonMat.append(tmpMat)

# for test 

# tmpmat = gower.gower_matrix(edibleSet[1])
# tmpDF = pd.DataFrame(tmpmat)
# tmpmat.to_excel('gowerMatTest.xlsx')
gowerEdibleMat = gower.gower_matrix(littleEdibleData)
poisonEdibleMat = gower.gower_matrix(littlePoisonData)

# %%
# import matplotlib.pyplot as plt

# model = DBSCAN(eps=0.5, min_samples=50)
# model(gowerEdibleMat[0])
# gowerEdibleMat[0]['cluster'] = model.fit_predict(gowerEdibleMat[0])

# # predict = pd.DataFrame(model.fit_predict(gowerEdibleMat[0]))
# # predict.columns = ['predict']
# # r = pd.concat([gowerEdibleMat[0], predict], axis = 1)
# # print(r)

# plt.figure(figsize = (8, 8))
# for i in range(-1, gowerEdibleMat[0]['cluster'].max() + 1):
#     plt.scatter(gowerEdibleMat[0].loc[gowerEdibleMat[0]['cluster'] == i, 'Annual Income (k$)'], gowerEdibleMat[0].loc[gowerEdibleMat[0]['cluster'] == i, 'Spending Score (1-100)'], 
#                     label = 'cluster ' + str(i))

# plt.legend()
# plt.title('eps = 0.5, min_samples = 2', size = 15)
# plt.xlabel('Annual Income', size = 12)
# plt.ylabel('Spending Score', size = 12)
# plt.show()

# %%
# dbscan_cluster = DBSCAN(eps=0.15, min_samples=20, metric="precomputed")
# dbscan_cluster.fit(gowerEdibleMat[0])
# edibleSet[0]["cluster"] = dbscan_cluster.labels_
# edibleSet[0]


# plt.figure(figsize = (8, 8))
# for i in range(-1, edibleSet[0]['cluster'].max() + 1):
#     plt.scatter(edibleSet[0].loc[edibleSet[0]['cluster'] == i, 'cap-diameter'], 
#                 edibleSet[0].loc[edibleSet[0]['cluster'] == i, 'stem-height'],
#                 label = 'cluster ' + str(i))

# plt.legend()
# plt.title('eps = 0.5, min_samples = 2', size = 15)
# plt.xlabel('cap-diameter', size = 12)
# plt.ylabel('stem-height', size = 12)
# plt.show()
dbscan_cluster = DBSCAN(eps=0.15, min_samples=20, metric="precomputed")
dbscan_cluster.fit(gowerEdibleMat)
littleEdibleData["cluster"] = dbscan_cluster.labels_

plt.figure(figsize = (8, 8))
for i in range(-1, littleEdibleData['cluster'].max() + 1):
    plt.scatter(littleEdibleData.loc[littleEdibleData['cluster'] == i, 'cap-diameter'], 
                littleEdibleData.loc[littleEdibleData['cluster'] == i, 'stem-height'],
                s = 3, 
                label = 'cluster ' + str(i))


plt.legend()
plt.title('eps = 0.5, min_samples = 2', size = 15)
plt.xlabel('cap-diameter', size = 12)
plt.ylabel('stem-height', size = 12)
plt.show()

# %%
tempDF = littleEdibleData[littleEdibleData["cluster"] == 1]
tempDF
# Out:
#        cap-diameter cap-shape   cap-color does-bruise-or-bleed   gill-color  \
# 58566         47.63    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58561         50.99    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58569         51.30    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58577         51.02    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58326         53.82    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58471         46.26    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58304         49.59    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58436         44.16    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58526         41.91    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58401         52.01    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# 58343         52.81    others  cap-yellow   no-bruise-or-bleed  gill-yellow
# ...

# %%
# sns.pairplot(littleEdibleData, hue = 'cluster')
# plt.show()
# # #pairplot with Seaborn
# # sns.pairplot(edibleSet[0] ,hue='cluster')
# # plt.show()
# Out:
# c:\Users\qksru\anaconda3\lib\site-packages\seaborn\_core.py:1057: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\qksru\Desktop\Univ\3_2\SoftWareApplication\termpj\DBScan_Gower.ipynb 셀 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/qksru/Desktop/Univ/3_2/SoftWareApplication/termpj/DBScan_Gower.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> sns.pairplot(littleEdibleData, hue = 'cluster')
#       <a href='vscode-notebook-cell:/c%3A/Users/qksru/Desktop/Univ/3_2/SoftWareApplication/termpj/DBScan_Gower.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# ...
